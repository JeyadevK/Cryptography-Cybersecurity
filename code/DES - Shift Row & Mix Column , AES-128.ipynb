# %% [markdown]
# ## 1) Code for Shift Rows and Mix Column in DES Algorithm

# %%
Matrix=[]
print("Enter the input Hexadecimal (4x4):\n")
for i in range(4):
    row=[]
    for j in range (4):
        elements=input()
        row.append(elements)
    Matrix.append(row)

print("The Input for the Shift row is :\n")
for i in range(4):
    for j in range(4):
        print(Matrix[i][j],end=" ")
    print()

print()
print("Performming Shift Rows ....")
print()
Matrix1=[]
for i in range(4):
    row=[]
    for j in range(4):
        row.append(0)
    Matrix1.append(row)
        
for i in range(4):
    for j in range(4):
        Matrix1[i][j]=Matrix[i][j] 


Matrix[1][0],Matrix[1][1],Matrix[1][2],Matrix[1][3]=Matrix1[1][1],Matrix1[1][2],Matrix1[1][3],Matrix1[1][0]
Matrix[2][0],Matrix[2][1],Matrix[2][2],Matrix[2][3]=Matrix1[2][2],Matrix1[2][3],Matrix1[2][0],Matrix1[2][1]
Matrix[3][0],Matrix[3][1],Matrix[3][2],Matrix[3][3]=Matrix1[3][3],Matrix1[3][0],Matrix1[3][1],Matrix1[3][2]

print()
print("After Performing Shift Rows")
for i in range(4):
    for j in range(4):
        print(Matrix[i][j],end=" ")
    print()
    
fixed_matrix=[[2,3,1,1],
              [1,2,3,1],
              [1,1,2,3],
              [3,1,1,2]]


def hex_to_bin(hexa):
    Binary=bin(int(hexa,16))[2:].zfill(8)
    return Binary

Binary_Matrix=[]
for i in Matrix:
    row=[]
    for j in i:
        element=hex_to_bin(j)
        row.append(element)
    Binary_Matrix.append(row)

print()
print("Binary of the matrix is :")
for i in range(4):
    for j in range(4):
        print(Binary_Matrix[i][j],end=" ")
    print()

def mix_columns(Matrix):
    Mix_col= []

    for i in range(4):
        mixed_column = []
        for j in range(4):
            total = 0
            for k in range(4):
                total ^= galois_mul(fixed_matrix[i][k], 
                                    matrix[k][j])
            mixed_column.append(total)
        Mix_col.append(mixed_column)
    return Mix_col

def galois_mul(a, b):
    p = 0
    for _ in range(8):
        if b & 1:
            p ^= a
        hi_bit_set = a & 0x80
        a <<= 1
        if hi_bit_set:
            a ^= 0x1B  # Irreducible polynomial for AES
        b >>= 1
    return p % 256

Mix_col = mix_columns(Binary_Matrix)

print()
def dec_to_hex(dec):
    hex_value = hex(dec)[2:].zfill(2).upper()  # Convert decimal to hexadecimal and zero-pad to ensure two characters
    return hex_value

Mix_column = []
for row in Mix_col:
    hex_row = [dec_to_hex(dec) for dec in row]
    Mix_column.append(hex_row)

print("After performing Mix Column :")
for i in range(4):
    for j in range(4):
        print(Mix_column[i][j],end=" ")
    print()
# Out:
# Enter the input Hexadecimal (4x4):
#
# EA
# 04
# 65
# 85
# 83
# 45
# 5D
# 96
# 5C
# 33
# 98
# B0
# F0
# 2D
# AD
# C5
# The Input for the Shift row is :
#
# EA 04 65 85
# 83 45 5D 96
# 5C 33 98 B0
# F0 2D AD C5
#
# Performming Shift Rows ....
#
# After Performing Shift Rows
# EA 04 65 85
# 45 5D 96 83
# 98 B0 5C 33
# C5 F0 2D AD
#
# Binary of the matrix is :
# 11101010 00000100 01100101 10000101
# 01000101 01011101 10010110 10000011
# 10011000 10110000 01011100 00110011
# 11000101 11110000 00101101 10101101
#
# Mix Column is :
# 5D AF 1A 11
# 16 85 9B 60
# D0 29 3C 8C
# 69 1A 3F 65

# %% [markdown]
# ## 2) Perform AES -128 bit Key Expansion

# %%
sbox = []

Round_con = [0x00000000, 0x01000000, 0x02000000,
		0x04000000, 0x08000000, 0x10000000, 
		0x20000000, 0x40000000, 0x80000000, 
		0x1b000000, 0x36000000]
		
def keyExpansion(key):
	w = [()]*44
	for i in range(4):
		w[i] = (key[4*i], key[4*i+1], key[4*i+2], key[4*i+3])

	for i in range(4, 44):
		temp = w[i-1]
		word = w[i-4]
		if i % 4 == 0:
			x = RotWord(temp)
			y = SubWord(x)
			R_con = Round_con [int(i/4)]
			temp = hex_xor(y, hex(R_con)[2:]) 
		word = ''.join(word)
		temp = ''.join(temp)
		xord = hex_xor(word, temp)
        w[i] = (xord[:2], xord[2:4], xord[4:6], xord[6:8])
        
    return w


def hex_xor(hex1, hex2):
    bin1 = hex_to_binary(hex1)
    bin2 = hex_to_binary(hex2)
    xord = int(bin1, 2) ^ int(bin2, 2)
    hexed = hex(xord)[2:]
    if len(hexed) != 8:
        hexed = '0' + hexed

    return hexed


def hex_to_binary(hex):
    return bin(int(str(hex), 16))


def RotWord(word):
    return word[1:] + word[:1]


def SubWord(word):
    sWord = ()
    for i in range(4):
        if word[i][0].isdigit() == False:
            row = ord(word[i][0]) - 86
        else:
            row = int(word[i][0])+1
        if word[i][1].isdigit() == False:
            col = ord(word[i][1]) - 86
        else:
            col = int(word[i][1])+1
        sBoxIndex = (row*16) - (17-col)
        piece = hex(sbox[sBoxIndex])[2:]
        if len(piece) != 2:
            piece = '0' + piece
        sWord = sWord + (piece,)
    return ''.join(sWord)

def prettyPrint(w):
    print("\n\nGerated Words from W0 to W43: \n")
    for i in range(len(w)):
        print("w" + str(i), "=", w[i][0], w[i][1], w[i][2], w[i][3])
    
def main():
    print("Enter the First four word in heaxdecimal (Countinuosly): ")
    key = []
    for i in range(16):
        elements=str(input())
        key.append(elements)
        #["84", "15", "71", "c9", "47", "d9", "e8", "59", "0c", "b7", "ad", "d6", "af", "7f", "67", "98"]
    w = keyExpansion(key)
    prettyPrint(w)

if __name__ == '__main__':
    main()
# Out:
# Enter the First four word in heaxdecimal (Countinuosly):
# 84
# 65
# 72
# f5
# 69
# af
# 7f
# d9
# 71
# e8
# 98
# c9
# 71
# 15
# 47
# b7
#
#
# Gerated Words from W0 to W43:
#
# w0 = 84 65 72 f5
# w1 = 69 af 7f d9
# w2 = 71 e8 98 c9
# w3 = 71 15 47 b7
# w4 = dc c5 db 56
# w5 = b5 6a a4 8f
# w6 = c4 82 3c 46
# w7 = b5 97 7b f1
# w8 = 56 e4 7a 83
# w9 = e3 8e de 0c
# w10 = 27 0c e2 4a
# w11 = 92 9b 99 bb
# w12 = 46 0a 90 cc
# w13 = a5 84 4e c0
# w14 = 82 88 ac 8a
# w15 = 10 13 35 31
# w16 = 33 9c 57 06
# w17 = 96 18 19 c6
# w18 = 14 90 b5 4c
# w19 = 04 83 80 7d
# w20 = cf 51 a8 f4
# w21 = 59 49 b1 32
# w22 = 4d d9 04 7e
# w23 = 49 5a 84 03
# w24 = 51 0e d3 cf
# w25 = 08 47 62 fd
# w26 = 45 9e 66 83
# w27 = 0c c4 e2 80
# w28 = 0d 96 1e 31
# w29 = 05 d1 7c cc
# w30 = 40 4f 1a 4f
# w31 = 4c 8b f8 cf
# w32 = b0 d7 94 18
# w33 = b5 06 e8 d4
# w34 = f5 49 f2 9b
# w35 = b9 c2 0a 54
# w36 = 8e b0 b4 4e
# w37 = 3b b6 5c 9a
# w38 = ce ff ae 01
# w39 = 77 3d a4 55
# w40 = 9f f9 48 bb
# ...
